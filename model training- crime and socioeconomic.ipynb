# %% [markdown]
# # PCA

# %% [markdown]
# ## 1. Read Data

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("evaldata_cleaned.csv")

# %% [markdown]
# ## 2. Define Variable

# %%
socio_cols = [
    "poverty_rate_pct",
    "median_household_income",
    "unemployment_rate_pct",
    "high_school_plus_rate_pct",
    "college_degree_rate_pct",
    "median_gross_rent",
    "median_home_value",
    "uninsured_rate_pct"
]

crime_cols = [
    "total_crimes",
    "violent_crimes",
    "property_crimes",
    "drug_crimes",
    "other_crimes",
    "total_population"
]

# %% [markdown]
# ## 3. Standardization

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_socio = scaler.fit_transform(df[socio_cols])
X_crime = scaler.fit_transform(df[crime_cols])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       1 from sklearn.preprocessing import StandardScaler
#       3 scaler = StandardScaler()
# ----> 5 X_socio = scaler.fit_transform(df[socio_cols])
#       6 X_crime = scaler.fit_transform(df[crime_cols])
#
# NameError: name 'df' is not defined
